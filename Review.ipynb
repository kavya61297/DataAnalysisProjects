# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import missingno as msno 
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
sns.set_style("whitegrid")

df = pd.read_csv("C:\Program Files\Scripts\CSVFiles\Reviews.csv")
df.shape
df.head() 
df.describe(include='all').T
# Out:
#                            count  unique
# Id                      568454.0     NaN  \
# ProductId                 568454   74258
# UserId                    568454  256059
# ProfileName               568428  218415
# HelpfulnessNumerator    568454.0     NaN
# HelpfulnessDenominator  568454.0     NaN
# Score                   568454.0     NaN
# Time                    568454.0     NaN
# Summary                   568427  295742
# Text                      568454  393579
#
#                                                                       top
# Id                                                                    NaN  \
# ProductId                                                      B007JFMH8M
# UserId                                                     A3OXHLG6DIBRW8
# ProfileName                                              C. F. Hill "CFH"
# HelpfulnessNumerator                                                  NaN
# HelpfulnessDenominator                                                NaN
# Score                                                                 NaN
# Time                                                                  NaN
# Summary                                                        Delicious!
# Text                    This review will make me sound really stupid, ...
#
#                         freq              mean              std          min
# Id                       NaN          284227.5    164098.679298          1.0  \
# ProductId                913               NaN              NaN          NaN
# UserId                   448               NaN              NaN          NaN
# ProfileName              451               NaN              NaN          NaN
# HelpfulnessNumerator     NaN          1.743817         7.636513          0.0
# HelpfulnessDenominator   NaN           2.22881          8.28974          0.0
# Score                    NaN          4.183199         1.310436          1.0
# Time                     NaN  1296256604.90242  48043312.332416  939340800.0
# Summary                 2462               NaN              NaN          NaN
# Text                     199               NaN              NaN          NaN
#
#                                  25%           50%           75%           max
# Id                         142114.25      284227.5     426340.75      568454.0
# ProductId                        NaN           NaN           NaN           NaN
# UserId                           NaN           NaN           NaN           NaN
# ProfileName                      NaN           NaN           NaN           NaN
# HelpfulnessNumerator             0.0           0.0           2.0         866.0
# HelpfulnessDenominator           0.0           1.0           2.0         923.0
# Score                            4.0           5.0           5.0           5.0
# Time                    1271289600.0  1311120000.0  1332720000.0  1351209600.0
# Summary                          NaN           NaN           NaN           NaN
# Text                             NaN           NaN           NaN           NaN
